# %%
# !pip install snownlp==0.11.1
# Out:
# Requirement already satisfied: snownlp==0.11.1 in /usr/local/lib/python3.7/dist-packages (0.11.1)

# %%
from snownlp import SnowNLP
from tqdm.notebook import tqdm
import pandas as pd

tqdm.pandas()

# %%
df = pd.read_table("BosonNLP_sentiment_score.txt",sep= " ",names=['key','score'])

# %%
key = df['key'].values.tolist()
score = df['score'].values.tolist()

# %%
print(key)
# Out:
# ['最尼玛', '扰民', 'fuck...', 'RNM', 'wcnmlgb', '2.5:', 'Fxxk', 'MLP', '吃哑巴亏', 'IAQI', 'MLGBD', 'NNND', 'MLGB.', '成甘', '最桑', '真无语', 'ＴＭ', '次奥次奥次奥', 'cnmd', 'MBD', 'NNDX', '水蛭', '美素丽', '草尼', '凌迟', '尼玛尼玛尼玛', '冠周炎', '加塞儿', '日尼玛', '朝仲', 'MD...', 'shit....', '人清', '风疹块', 'ＴＭＤ', '真桑心', 'NND...', '延机', '毛明天', '逆流', '肺病', '5555ACCOUNT_', 'NTR', 'Shit.', 'nnd.', '化学药品', '章珊珊', '桑心桑', 'mbd', '尼玛让', '重启后', '太桑', 'mlgbd', 'DIU', 'mmmp', 'no....', 'ohshit', 'tmd.', '让不让', '肠痉挛', '欺人太甚', '13803883303', 'Crixus', 'NDYD', 'TouchTao', 'fxxking', 'no..', '求淡定', '电子电路', '费爱华', '路雪旗', '甘嘎', 'MLGB...', 'NNd', 'QNMLGBD', 'TMd', 'mlp', '先好', '半仲', '拉普拉斯', '梗阻', '欧尼玛', '解又', '解成', '遗忘症', '马丹', '毛为毛', '40.2', '55555......', '555555555555555555', '@／', 'MLGBZ', 'NNDACCOUNT_', 'O33', 'SOB', 'Upset', '二三十分', '先黎', '吐尼玛', '善宇', '回天无力', '忴', '正爽', '趾头', '醒仲', 'fuckfuckfuck', '么劲', '桑心好', '55555555555', '尼玛阿', '下泻', 'TNND', '100.91万亿', '3gs', '555555.', '5555555555555555555', '776803828', 'Fxxx', 'OS6.1', 'Scheisse', 'WQNMLGBD', 'barely', 'cao.', 'cazzo', 'cnmgb', 'mlgbz', 'nngx', 'sleeplessness', 'wcnm', '€|', '个协', '剮', '吾通真', '心欲', '次奥真', '武哲', '毛明明', '毛用', '法克法克法克', '玛淡', '自寻短见', '负号', '麻尼', 'Ｔｍ', 'NND', 'nnd', '5555555555555', '下泄', 'mmp', '@／：', 'WTF.', 'aaaaaaaaaaa', 'nndx', '五六七八九十', '仲吾训', '傅里', '六点二', '划子', '又贵', '含家', '噶得', '孙某', '尼玛得', '异化', '慛', '拉关系', '林靖恩', '求复活', '热尼玛', '猛长', '玛火大', '绦虫', '跣', '邓某', '钟才能', '钱伯', '铅块', '饥寒交加', 'ｃａｏ', '出乱子', '肺痨', '555555555', 'Shit', '欲哭无泪', '泥煤', 'cnmlgb', 'Md', '次奥次奥', '法克', 'WTH', '英雄汉', '训吾', '躁狂症', 'mlgb', '无名火', '窝火', '44.4%', '55...', '5555....', '55555555ACCOUNT_', '8149', '95583', 'FUCKACCOUNT_', 'KMN', 'MlGB', 'Motherfucker', 'PPT...', 'TAT.....', 'TNND.', 'cityrail', 'consulting', 'database', 'division', 'fml', 'fuxking', 'myki', 'nnnd', 'odk', 'wqnmlgbd', '一個咁', '一點氣', '保释金', '兰可儿', '出口商', '卡费', '卫生费', '喉风', '姚非', '尤桑', '尼玛地', '尼玛白', '尼玛的尼玛', '布鲁姆米兰达', '忟', '我连', '我长', '数据表', '日放', '查档', '毛训', '清洲', '玛得', '盗窃罪', '神经炎', '能教', '解人', '逐句', '马月才', '黑成甘', 'KAO', '谢特', '精神损失费', '救救', 'NND.', 'TMMD', '智牙', 'TMD.', '555555', 'WCNMLGB', '钟仲', '鬼天', '尼玛玛', '艹', 'WTF', '0.2kg', '010-67679910', '7456', '8437', 'CONTROL', 'Delayed', 'FXXX', 'MLGBZD', 'Mmd', 'OS6.0.1', 'QNMGB', 'STRESS', 'SUCKS', 'TTTTTTTTTTTTTTTT', 'bothering', 'cao..', 'ctmd', 'disorder', 'downdowndown', 'h7n9.', 'insomnia.', 'mastercard', 'qua', 'sad..', 'wcnmgb', 'ㄩ', '一病病', '一種錯', '三点.', '三酉', '么非', '五爽', '仲洗', '伯言', '八点二', '八点二十五', '六点七', '冷醒', '办发', '困人', '太生', '孟钰', '尼玛刚', '尼玛加', '尼玛尼', '崔钟显', '平一波', '戈比', '梦中梦', '横眉竖眼', '次奥阿', '永胜县', '消音器', '班仲', '甘声', '甘放', '白乎乎', '百分之六', '类人猿', '组织液', '花克', '解我仲', '谢特谢特', '遏止', '金贵', '青红皂白', '鬼剃头', 'Ｆｕｃｋ', 'ＮＮＤ', 'MMMP', 'MD.', '祸不单行', '毛雨', 'wtf', '神经衰弱', '闹肚子', 'MD', 'NNGX', 'nmd', 'MMP', '救命', 'qnmlgb', 'SHIT', '命苦', 'MLGB', '越霖', 'OS6.1.3', '圣姑', '塔玛', '翻胃', '次奥', 'CNMLGB', '好端端', '%%￥', '19.1KB', '2Kg', '555.....', '555555...', '5555555ACCOUNT_', '7828', 'FuCK', 'GNM', 'MD....', 'MDMDMD', 'MLGP', 'Merde', 'NMBD', 'PSN', 'QQQQQQQQQQQQQQQQ', 'S60V3', 'Shit...', 'TAT....', 'T_TT_TT_TT_T', 'WCNM', 'WOCAO', 'aware', 'ctrl+s', 'e109', 'hem', 'marre', 'midterms', 'mlg', 'ntmd', 'paperpass', 'ppt...', 'presen', 'puke', 'shi..', 'shitshitshit', 'tpo', 'zemi', '′⌒', '一個見', '一坐坐', '一摊摊', '一顿顿', '两三点', '五训', '代数和', '令狐聪', '何解会', '六一一点', '冷得', '十二点十五', '历史唯物主义', '又浪', '反光', '叶菡丹', '哈切列', '国别', '天天学', '学硕', '导护', '尼玛老', '我我', '抽搭', '搬运费', '文山会海', '无野', '水荒', '热阿阿阿', '焦甘', '猪瘟', '甘迟训', '痛切', '百分之七', '皇历', '真无良', '稳操胜券', '窦性', '腕骨', '药疹', '菲兹', '蚣', '西土城', '都木', '醒后', '醒好', '重启中', '錨', '钟云', '钡餐', '阴工', '除臭剂', '马勒比', '马和', '黄牌警告', '２０００', '卄', '次奥尼玛', '毛木', '门卡', 'TMB', 'Mlgb', 'Tmd', 'NMD', '拉肚子', '周喜军', '草尼玛', '恨死', '发冷', 'tnn', '钟都仲', 'md', '倒霉', 'fuckACCOUNT_', '麻醉针', '尼玛尼玛', '5555555555', '阴公', '落枕', '泰诺', '电钻', '55555555555555555', '克奥', '孙维', '我草', '桑心', '牙髓', '袁泽', '旧病', '麦粒肿', 'nmlgb', '反胃', '恶梦', '蓝可儿', '尼玛勒', '555555555555', '扁桃体', '可恶', 'T_TT_T', 'caonima', '道勋', 'PSI', '寒心', '药罐子', 'CNM', 'cnm', '气死', ' ...

# %%
print(score)
# Out:
# [-6.7040001263699995, -6.497564458669999, -6.3296339043300005, -6.21861284426, -5.96710044003, -5.90459648251, -5.87247473641, -5.87247473641, -5.77120419579, -5.771078371230001, -5.694081915009999, -5.66228462641, -5.6045774358300005, -5.6045774358300005, -5.6045774358300005, -5.6045774358300005, -5.6045774358300005, -5.59258287133, -5.54446545761, -5.502801098430001, -5.48173951768, -5.48173951768, -5.48173951768, -5.48173951768, -5.46005372985, -5.42622557462, -5.41616190446, -5.41616190446, -5.41616190446, -5.41616190446, -5.3474609293699995, -5.3474609293699995, -5.3474609293699995, -5.3474609293699995, -5.3474609293699995, -5.304404434019999, -5.27532412618, -5.27532412618, -5.27532412618, -5.27532412618, -5.23415259142, -5.1993896588999995, -5.1993896588999995, -5.1993896588999995, -5.1993896588999995, -5.1993896588999995, -5.1993896588999995, -5.17297280471, -5.1192353401099995, -5.1192353401099995, -5.1192353401099995, -5.1189980795, -5.102415881080001, -5.03436441522, -5.03436441522, -5.03436441522, -5.03436441522, -5.03436441522, -5.03436441522, -5.00471310388, -4.96442566573, -4.94418689774, -4.94418689774, -4.94418689774, -4.94418689774, -4.94418689774, -4.94418689774, -4.94418689774, -4.94418689774, -4.94418689774, -4.94418689774, -4.8805433121399995, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.8479946724500005, -4.77985774401, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.744927689730001, -4.7446714036, -4.70860539331, -4.67161459877, -4.666174592169999, -4.66075280423, -4.64511639079, -4.64159586593, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.63392712861, -4.60859503941, -4.59270746389, -4.554586570030001, -4.55444896108, -4.54707249255, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.5136689933800005, -4.513368145059999, -4.51330796786, -4.47412704066, -4.47143199171, -4.467497757169999, -4.465449813319999, -4.45849219995, -4.45507934758, -4.44183525598, -4.436485212209999, -4.42722075911, -4.42722075911, -4.42722075911, -4.40929165229, -4.40822546792, -4.40793307431, -4.39136025706, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199996, -4.3824674333199 ...

# %%
#res = (arr - arr.min())/(arr.max() - arr.min()) * width + start

# %%
url_in = 'https://raw.githubusercontent.com/AlexRanzh/disaster-setiment-analysis/main/weibo-data-cleaned/mid_flood.csv'
url_post = 'https://raw.githubusercontent.com/AlexRanzh/disaster-setiment-analysis/main/weibo-data-cleaned/after_flood.csv'
url_pre = 'https://raw.githubusercontent.com/AlexRanzh/disaster-setiment-analysis/main/weibo-data-cleaned/pre_flood.csv'
df_in = pd.read_csv(url_in, usecols=['id', 'text_pre_list'])
df_post = pd.read_csv(url_post, usecols=['id', 'text_pre_list'])
df_pre = pd.read_csv(url_pre, usecols=['id', 'text_pre_list'])

# %% [markdown]
# Show some examples:

# %%
print(df_in.head(5))
print(df_post.head(5))
print(df_pre.head(5))
# Out:
#                  id                                      text_pre_list
# 0  4689452229725981                       ['懂事', '孩子', '没有', '糖', '吃']
# 1  4689453065443305  ['老家', '房子', '听说', '都', '已经', '坍塌', '幸运的', '没有...
# 2  4689453438735200  ['真的', '救', '同学', '暴雨', '导致', '桥', '坍塌', '火车',...
# 3  4689453714769972  ['无人', '问晋', '河南', '暴雨', '晋城', '暴雨', '好多', '泥石...
# 4  4689454428588921  ['原本', '三个', '半个', '小时', '路程', '走', '小时', '下雨'...
#                  id                                      text_pre_list
# 0  4690901877655172  ['微薄', '之力', '唯愿', '天佑', '中华', '日', '金榜题名', '定...
# 1  4690902155267478  ['包裹', '平遥', '古城', '不是', '艺术', '正在', '发生', '无法...
# 2  4690902101264925  ['我靠', '今天', '看到', '张艺兴', '飞天', '公益', '好多', '代...
# 3  4690902230502092  ['周深', '求生', '米', '一起', '捐助', '山西', '链接', '二维码...
# 4  4690902545859220  ['民族', '企业', '笔芯', '明目张胆', '拉', '踩', '偷偷', '斗鱼...
#                  id                                      text_pre_list
# 0  4687749565644973  ['秋风', '猎', '红旗', '晨曦', '迎', '华诞', '庆祝', '新', ...
# 1  4687763977275545  ['查', '隐患', '做', '宣传', '安保', '工作', '保驾护航', '扎实...
# 2  4687775381586971  ['公安部', '交管局', '提示', '高速公路', '行车', '注意安全', '国庆...
# 3  4687780363370863  ['公安部', '交管局', '提示', '高速公路', '行车', '注意安全', '国庆...
# 4  4687781471715682  ['近日', '山西', '运城', '暴雨', '导致', '村民', '家', '猪舍'...

# %%
def getscore(line):
    score_list  = [score[key.index(x)] for x in line if(x in key)]
    return sum(score_list)

# %%
def helper(line):
    line = line.replace("'", '')
    line = line.replace("[", '')
    line = line.replace("]", '')
    out = line.split(", ")
    return out

# %%
def normalize(score, m1, n1):
  if score > m1:
    score = m1
  if score < n1:
    score = n1

  if(score > 0):
    return score * 5 / m1
  elif(score < 0):
    return (score - n1) * 5 / (0 - n1) - 5
  else:
    return 0

# %%
df_in["text_modified"] = df_in["text_pre_list"].apply(helper)
df_in["raw_score"] = df_in["text_modified"].progress_apply(getscore)
# Out:
#   0%|          | 0/15284 [00:00<?, ?it/s]

# %%
df_in["normalized_score"] = df_in["raw_score"].progress_apply(normalize, m1 = 35, n1 = -11)
# Out:
#   0%|          | 0/15284 [00:00<?, ?it/s]

# %%
df_post["text_modified"] = df_post["text_pre_list"].apply(helper)
df_post["raw_score"] = df_post["text_modified"].progress_apply(getscore)
# Out:
#   0%|          | 0/6701 [00:00<?, ?it/s]

# %%
df_post["normalized_score"] = df_post["raw_score"].progress_apply(normalize, m1 = 70, n1 = -13)
# Out:
#   0%|          | 0/6701 [00:00<?, ?it/s]

# %%
df_pre["text_modified"] = df_pre["text_pre_list"].apply(helper)
df_pre["raw_score"] = df_pre["text_modified"].progress_apply(getscore)
# Out:
#   0%|          | 0/5773 [00:00<?, ?it/s]

# %%
df_pre["normalized_score"] = df_pre["raw_score"].progress_apply(normalize, m1 = 35, n1 = -13)
# Out:
#   0%|          | 0/5773 [00:00<?, ?it/s]

# %%
df_pre.drop('text_modified', axis=1, inplace=True)

# %%
print(df_pre)
print("Positive:", len([x for x in df_pre["normalized_score"] if x >= 0]))
print("Negative:", len([x for x in df_pre["normalized_score"] if x <= 0]))
# Out:
#                     id  ... normalized_score
# 0     4687749565644973  ...         5.000000
# 1     4687763977275545  ...         1.762369
# 2     4687775381586971  ...         4.184594
# 3     4687780363370863  ...         4.184594
# 4     4687781471715682  ...         0.871628
# ...                ...  ...              ...
# 5768  4689452192760337  ...         1.168998
# 5769  4689452004021748  ...         0.372305
# 5770  4689452183854318  ...         0.713905
# 5771  4689452096555216  ...        -0.098152
# 5772  4689452217401715  ...        -1.547848
#
# [5773 rows x 4 columns]
# Positive: 3660
# Negative: 2258

# %%
df_in.drop('text_modified', axis=1, inplace=True)

# %%
print(df_in)
print("Positive:", len([x for x in df_in["normalized_score"] if x >= 0]))
print("Negative:", len([x for x in df_in["normalized_score"] if x <= 0]))
# Out:
#                      id  ... normalized_score
# 0      4689452229725981  ...         0.322505
# 1      4689453065443305  ...         0.081419
# 2      4689453438735200  ...        -2.852756
# 3      4689453714769972  ...        -3.084190
# 4      4689454428588921  ...        -2.558963
# ...                 ...  ...              ...
# 15279  4690901085193482  ...         0.429377
# 15280  4690901077328572  ...         4.920273
# 15281  4690901299628572  ...         1.013850
# 15282  4690901547092803  ...         1.787479
# 15283  4690901537916305  ...         0.248290
#
# [15284 rows x 4 columns]
# Positive: 11780
# Negative: 3755

# %%
df_post.drop('text_modified', axis=1, inplace=True)

# %%
print(df_post)
print("Positive:", len([x for x in df_post["normalized_score"] if x >= 0]))
print("Negative:", len([x for x in df_post["normalized_score"] if x <= 0]))
# Out:
#                     id  ... normalized_score
# 0     4690901877655172  ...         0.519702
# 1     4690902155267478  ...         0.151657
# 2     4690902101264925  ...         3.181157
# 3     4690902230502092  ...         0.960492
# 4     4690902545859220  ...         0.016917
# ...                ...  ...              ...
# 6696  4696299851220769  ...         1.347835
# 6697  4696306218440728  ...         0.028235
# 6698  4696307552486120  ...         5.000000
# 6699  4696314686738706  ...         2.241076
# 6700  4696321896484116  ...         0.763268
#
# [6701 rows x 4 columns]
# Positive: 5946
# Negative: 790

# %%
df_pre.to_csv('pre_flood_with_score.csv',index=False)

# %%
df_in.to_csv('mid_flood_with_score.csv',index=False)

# %%
df_post.to_csv('post_flood_with_score.csv',index=False)
